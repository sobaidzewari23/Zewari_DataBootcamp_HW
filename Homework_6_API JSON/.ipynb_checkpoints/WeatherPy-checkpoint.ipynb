# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['kavieng',
#  'puerto ayora',
#  'faya',
#  'asau',
#  'mys shmidta',
#  'chuy',
#  'bud',
#  'airai',
#  'coihaique',
#  'ushuaia',
#  'samalaeulu',
#  'el alto',
#  'dunedin',
#  'mahebourg',
#  'rylsk',
#  'maningrida',
#  'nuevo progreso',
#  'hovd',
#  'barrow',
#  'nipawin',
#  'laela',
#  'belushya guba',
#  'hermanus',
#  'rikitea',
#  'ancud',
#  'cayenne',
#  'coruripe',
#  'bartica',
#  'atuona',
#  'taybad',
#  'san jose',
#  'toba',
#  'hasaki',
#  'acapulco',
#  'jamestown',
#  'seminole',
#  'licheng',
#  'isla vista',
#  'avarua',
#  'husavik',
#  'vaini',
#  'new norfolk',
#  'vengerovo',
#  'kumylzhenskaya',
#  'fort nelson',
#  'kaitangata',
#  'hobart',
#  'ribeira grande',
#  'srednekolymsk',
#  'sandpoint',
#  'victoria',
#  'barentsburg',
#  'hithadhoo',
#  'busselton',
#  'isangel',
#  'ngunguru',
#  'kapaa',
#  'east london',
#  'mataura',
#  'saint-philippe',
#  'port-gentil',
#  'vaitupu',
#  'bredasdorp',
#  'eureka',
#  'broome',
#  'dikson',
#  'haines junction',
#  'butaritari',
#  'albany',
#  'bethel',
#  'yulara',
#  'qaanaaq',
#  'tasiilaq',
#  'sao filipe',
#  'issoudun',
#  'villazon',
#  'naze',
#  'saldanha',
#  'devils lake',
#  'punta arenas',
#  'dzaoudzi',
#  'byron bay',
#  'saskylakh',
#  'hamilton',
#  'taolanaro',
#  'port elizabeth',
#  'norrtalje',
#  'evreux',
#  'gat',
#  'rocha',
#  'mehamn',
#  'mitu',
#  'ponta do sol',
#  'illoqqortoormiut',
#  'vila velha',
#  'hilo',
#  'chokwe',
#  'luderitz',
#  'pepel',
#  'ahipara',
#  'sao jose da coroa grande',
#  'tazovskiy',
#  'shimoda',
#  'pevek',
#  'lebu',
#  'tuktoyaktuk',
#  'jalu',
#  'angoche',
#  'skelleftea',
#  'meulaboh',
#  'moultrie',
#  'taseyevo',
#  'ballina',
#  'salme',
#  'norman wells',
#  'bambanglipuro',
#  'bunbury',
#  'faanui',
#  'turaiyur',
#  'narsaq',
#  'grand-santi',
#  'edd',
#  'plettenberg bay',
#  'the valley',
#  'buraydah',
#  'mingaora',
#  'port hedland',
#  'westport',
#  'tunduru',
#  'raymond',
#  'torbay',
#  'bluff',
#  'ilulissat',
#  'atambua',
#  'pisco',
#  'samusu',
#  'launceston',
#  'labuhan',
#  'mar del plata',
#  'bengkulu',
#  'sakakah',
#  'yellowknife',
#  'grindavik',
#  'ha tinh',
#  'lipin bor',
#  'lagoa',
#  'palmer',
#  'tomar do geru',
#  'port alfred',
#  'castro',
#  'vardo',
#  'zemio',
#  'cherskiy',
#  'shingu',
#  'san carlos de bariloche',
#  'kedrovyy',
#  'chokurdakh',
#  'havre',
#  'resplendor',
#  'berdigestyakh',
#  'sheltozero',
#  'nikolskoye',
#  'upernavik',
#  'ust-maya',
#  'vuktyl',
#  'sitka',
#  'dong hoi',
#  'coquimbo',
#  'iracoubo',
#  'vao',
#  'miri',
#  'walvis bay',
#  'san patricio',
#  'soyo',
#  'sinjah',
#  'bagdarin',
#  'amderma',
#  'touros',
#  'lingyuan',
#  'kudahuvadhoo',
#  'georgetown',
#  'paracuru',
#  'suoyarvi',
#  'ola',
#  'merauke',
#  'bababe',
#  'olafsvik',
#  'sumbawa',
#  'anse-bertrand',
#  'champerico',
#  'mundra',
#  'goderich',
#  'nizhneyansk',
#  'la florida',
#  'qaqortoq',
#  'tezu',
#  'lawton',
#  'road town',
#  'hihifo',
#  'bambous virieux',
#  'attawapiskat',
#  'de aar',
#  'klaksvik',
#  'luoyang',
#  'zhuhai',
#  'goulburn',
#  'yeniseysk',
#  'huazolotitlan',
#  'marienburg',
#  'acuna',
#  'mayo',
#  'port moresby',
#  'sentyabrskiy',
#  'ridgecrest',
#  'lugoba',
#  'yar-sale',
#  'macia',
#  'saint george',
#  'bemidji',
#  'lardos',
#  'pochutla',
#  'mrirt',
#  'cam pha',
#  'semporna',
#  'tiksi',
#  'pemba',
#  'boende',
#  'mount gambier',
#  'strezhevoy',
#  'hun',
#  'rothenbach',
#  'tabiauea',
#  'laguna',
#  'kedgwick',
#  'jacareacanga',
#  'taburi',
#  'arraial do cabo',
#  'jilib',
#  'conceicao do araguaia',
#  'alasehir',
#  'komatipoort',
#  'praxedis guerrero',
#  'fallon',
#  'fernie',
#  'maraba',
#  'midland',
#  'turukhansk',
#  'macae',
#  'zyryanovsk',
#  'fort smith',
#  'esperance',
#  'assiniboia',
#  'sheridan',
#  'san quintin',
#  'cape town',
#  'constitucion',
#  'ambilobe',
#  'bumba',
#  'iqaluit',
#  'ambunti',
#  'gushikawa',
#  'fairbanks',
#  'oranjemund',
#  'grand river south east',
#  'axim',
#  'kon tum',
#  'codrington',
#  'diamantino',
#  'te anau',
#  'kuche',
#  'sosva',
#  'peruibe',
#  'moussoro',
#  'yurga',
#  'tomohon',
#  'zhigansk',
#  'matara',
#  'one hundred mile house',
#  'san ramon',
#  'bubaque',
#  'uni',
#  'tuatapere',
#  'dzilam gonzalez',
#  'inta',
#  'pietarsaari',
#  'teknaf',
#  'komsomolskiy',
#  'bayonne',
#  'ambon',
#  'palana',
#  'taltal',
#  'yenangyaung',
#  'bilma',
#  'boyolangu',
#  'longyearbyen',
#  'izazi',
#  'crab hill',
#  'kahului',
#  'kaohsiung',
#  'galbshtadt',
#  'turbat',
#  'marevo',
#  'rawannawi',
#  'harper',
#  'mount kisco',
#  'muyezerskiy',
#  'buala',
#  'ayan',
#  'teguise',
#  'potam',
#  'lufilufi',
#  'albania',
#  'minyar',
#  'havre-saint-pierre',
#  'veraval',
#  'khatanga',
#  'thompson',
#  'bulgan',
#  'anderson',
#  'meyungs',
#  'barawe',
#  'mutum',
#  'rivne',
#  'tsihombe',
#  'aflu',
#  'narimanov',
#  'luanda',
#  'ziro',
#  'dewas',
#  'melfi',
#  'cabo san lucas',
#  'olinda',
#  'itarema',
#  'hanna',
#  'jalingo',
#  'namibe',
#  'vung tau',
#  'port blair',
#  'truth or consequences',
#  'sibolga',
#  'dingle',
#  'saint-joseph',
#  'bathsheba',
#  'agadir',
#  'kandrian',
#  'padilla',
#  'nyurba',
#  'bereda',
#  'chiclana',
#  'cosamaloapan',
#  'luena',
#  'ossora',
#  'buchanan',
#  'pokhara',
#  'coahuayana',
#  'rundu',
#  'clyde river',
#  'prieska',
#  'portland',
#  'det udom',
#  'rincon',
#  'northam',
#  'linhares',
#  'tukrah',
#  'tarudant',
#  'kodiak',
#  'oudtshoorn',
#  'burnie',
#  'labuan',
#  'zaysan',
#  'deh rawud',
#  'tenenkou',
#  'khuzdar',
#  'sumbe',
#  'beira',
#  'santa cruz cabralia',
#  'xining',
#  'revda',
#  'kissidougou',
#  'grand island',
#  'arang',
#  'micheweni',
#  'jian',
#  'sao joao da barra',
#  'severo-kurilsk',
#  'kuznechnoye',
#  'zhangjiakou',
#  'east peoria',
#  'susurluk',
#  'carbonia',
#  'shahrud',
#  'shkotovo-26',
#  'chicama',
#  'opobo',
#  'voerde',
#  'hammerfest',
#  'hefei',
#  'muros',
#  'sjovegan',
#  'saint-pierre',
#  'ribnitz-damgarten',
#  'baruun-urt',
#  'buon me thuot',
#  'bariri',
#  'mitchell',
#  'puerto del rosario',
#  'kardla',
#  'inhambane',
#  'sofiysk',
#  'provideniya',
#  'kavaratti',
#  'seoul',
#  'baiquan',
#  'kakinada',
#  'flagstaff',
#  'hambantota',
#  'segovia',
#  'luza',
#  'nanortalik',
#  'viedma',
#  'blackwater',
#  'guanay',
#  'barcelos',
#  'cabedelo',
#  'ocos',
#  'namatanai',
#  'semenivka',
#  'linda',
#  'artyk',
#  'talnakh',
#  'salinopolis',
#  'novikovo',
#  'glace bay',
#  'port macquarie',
#  'lasa',
#  'rampura',
#  'galesong',
#  'agua verde',
#  'shasta lake',
#  'lompoc',
#  'saleaula',
#  'numata',
#  'burica',
#  'souillac',
#  'itoman',
#  'beringovskiy',
#  'aklavik',
#  'malwan',
#  'dali',
#  'eirunepe',
#  'camden',
#  'sainte-maxime',
#  'poum',
#  'colares',
#  'atocha',
#  'egvekinot',
#  'sivas',
#  'comodoro rivadavia',
#  'sembakung',
#  'san policarpo',
#  'bonavista',
#  'dauphin',
#  'north vanlaiphai',
#  'taraz',
#  'lorengau',
#  'anadyr',
#  'volchikha',
#  'marshall',
#  'linchuan',
#  'petropavlovsk-kamchatskiy',
#  'thinadhoo',
#  'lingao',
#  'lavrentiya',
#  'kamina',
#  'carupano',
#  'honningsvag',
#  'tessalit',
#  'amambai',
#  'margate',
#  'garmsar',
#  'amarpatan',
#  'tiarei',
#  'rio grande',
#  'claveria',
#  'awjilah',
#  'nichinan',
#  'nong phai',
#  'deputatskiy',
#  'tungor',
#  'zolotinka',
#  'xuddur',
#  'hit',
#  'kalat',
#  'melville',
#  'soto la marina',
#  'yakeshi',
#  'kibala',
#  'grimshaw',
#  'payo',
#  'luwingu',
#  'ouegoa',
#  'tucuman',
#  'gimbi',
#  'terenos',
#  'nanning',
#  'hirara',
#  'pingliang',
#  'korla',
#  'mount pleasant',
#  'krasnoselkup',
#  'salvador',
#  'zhigalovo',
#  'fortuna',
#  'sorong',
#  'ugoofaaru',
#  'honiara',
#  'green river',
#  'loa janan',
#  'semey',
#  'karasjok',
#  'dandong',
#  'alice springs',
#  'carutapera',
#  'port hardy',
#  'naro moru',
#  'vagay',
#  'gao',
#  'jataizinho',
#  'salalah',
#  'hofn',
#  'katsuura',
#  'sabang',
#  'kuching',
#  'qabis',
#  'rio gallegos',
#  'prince rupert',
#  'muravlenko',
#  'marilia',
#  'shitanjing',
#  'caracollo',
#  'hobyo',
#  'saint anthony',
#  'quelimane',
#  'prainha',
#  'dahra',
#  'carnarvon',
#  'juneau',
#  'portsmouth',
#  'ravar',
#  'kangaatsiaq',
#  'monteria',
#  'mayumba',
#  'villamontes',
#  'kirakira',
#  'lindi',
#  'normandin',
#  'norsup',
#  'kibuye',
#  'batagay-alyta',
#  'krasnorechenskiy',
#  'waipawa',
#  'ngukurr',
#  'karratha',
#  'kurchum',
#  'moose factory',
#  'juegang',
#  'sembe',
#  'nakusp',
#  'bulawayo',
#  'bolungarvik',
#  'trofors',
#  'mendahara',
#  'karaul',
#  'ormara',
#  'kawalu',
#  'barguzin',
#  'idritsa',
#  'mamallapuram',
#  'richards bay',
#  'chaumont',
#  'alotau',
#  'ostrovnoy',
#  'los llanos de aridane',
#  'kidal',
#  'gazni',
#  'palu',
#  'mega',
#  'alihe',
#  'beech grove',
#  'scarborough',
#  'guerrero negro',
#  'katobu',
#  'vila franca do campo',
#  'tigil',
#  'mirabad',
#  'koungou',
#  'alyangula',
#  'bontang',
#  'finschhafen',
#  'saint-francois',
#  'cibinong',
#  'tanete',
#  'rungata',
#  'agfalva',
#  'ulaangom',
#  'mandalgovi',
#  'lazaro cardenas',
#  'gezing',
#  'nioro']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
response = requests.get(query_url + "vaini").json()
response
# Out:
# {'coord': {'lon': 74.49, 'lat': 15.34},
#  'weather': [{'id': 701,
#    'main': 'Mist',
#    'description': 'mist',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 73.4,
#   'pressure': 1011,
#   'humidity': 88,
#   'temp_min': 73.4,
#   'temp_max': 73.4},
#  'visibility': 8000,
#  'wind': {'speed': 3.36, 'deg': 270},
#  'clouds': {'all': 40},
#  'dt': 1563419071,
#  'sys': {'type': 1,
#   'id': 9229,
#   'message': 0.007,
#   'country': 'IN',
#   'sunrise': 1563410399,
#   'sunset': 1563456963},
#  'timezone': 19800,
#  'id': 1273574,
#  'name': 'Vaini',
#  'cod': 200}

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
counter = 1

print("Beginning Data Retrieval")
print("--------------------------------")

for city in cities:

    response = requests.get(query_url + city).json()

    try:
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {counter} | {city}")
        counter+=1
        time.sleep(1)
    except KeyError:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 | kavieng
# Processing Record 2 | puerto ayora
# Processing Record 3 | faya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 | chuy
# Processing Record 5 | bud
# Processing Record 6 | airai
# Processing Record 7 | coihaique
# Processing Record 8 | ushuaia
# City not found. Skipping...
# Processing Record 9 | el alto
# Processing Record 10 | dunedin
# Processing Record 11 | mahebourg
# Processing Record 12 | rylsk
# Processing Record 13 | maningrida
# Processing Record 14 | nuevo progreso
# Processing Record 15 | hovd
# Processing Record 16 | barrow
# Processing Record 17 | nipawin
# Processing Record 18 | laela
# City not found. Skipping...
# Processing Record 19 | hermanus
# Processing Record 20 | rikitea
# Processing Record 21 | ancud
# Processing Record 22 | cayenne
# Processing Record 23 | coruripe
# Processing Record 24 | bartica
# Processing Record 25 | atuona
# Processing Record 26 | taybad
# Processing Record 27 | san jose
# Processing Record 28 | toba
# Processing Record 29 | hasaki
# Processing Record 30 | acapulco
# Processing Record 31 | jamestown
# Processing Record 32 | seminole
# Processing Record 33 | licheng
# Processing Record 34 | isla vista
# Processing Record 35 | avarua
# Processing Record 36 | husavik
# Processing Record 37 | vaini
# Processing Record 38 | new norfolk
# Processing Record 39 | vengerovo
# Processing Record 40 | kumylzhenskaya
# Processing Record 41 | fort nelson
# Processing Record 42 | kaitangata
# Processing Record 43 | hobart
# Processing Record 44 | ribeira grande
# Processing Record 45 | srednekolymsk
# Processing Record 46 | sandpoint
# Processing Record 47 | victoria
# City not found. Skipping...
# Processing Record 48 | hithadhoo
# Processing Record 49 | busselton
# Processing Record 50 | isangel
# Processing Record 51 | ngunguru
# Processing Record 52 | kapaa
# Processing Record 53 | east london
# Processing Record 54 | mataura
# Processing Record 55 | saint-philippe
# Processing Record 56 | port-gentil
# City not found. Skipping...
# Processing Record 57 | bredasdorp
# Processing Record 58 | eureka
# Processing Record 59 | broome
# Processing Record 60 | dikson
# Processing Record 61 | haines junction
# Processing Record 62 | butaritari
# Processing Record 63 | albany
# Processing Record 64 | bethel
# Processing Record 65 | yulara
# Processing Record 66 | qaanaaq
# Processing Record 67 | tasiilaq
# Processing Record 68 | sao filipe
# Processing Record 69 | issoudun
# City not found. Skipping...
# Processing Record 70 | naze
# Processing Record 71 | saldanha
# Processing Record 72 | devils lake
# Processing Record 73 | punta arenas
# Processing Record 74 | dzaoudzi
# Processing Record 75 | byron bay
# Processing Record 76 | saskylakh
# Processing Record 77 | hamilton
# City not found. Skipping...
# Processing Record 78 | port elizabeth
# Processing Record 79 | norrtalje
# Processing Record 80 | evreux
# Processing Record 81 | gat
# Processing Record 82 | rocha
# Processing Record 83 | mehamn
# Processing Record 84 | mitu
# Processing Record 85 | ponta do sol
# City not found. Skipping...
# Processing Record 86 | vila velha
# Processing Record 87 | hilo
# City not found. Skipping...
# Processing Record 88 | luderitz
# Processing Record 89 | pepel
# Processing Record 90 | ahipara
# Processing Record 91 | sao jose da coroa grande
# Processing Record 92 | tazovskiy
# Processing Record 93 | shimoda
# Processing Record 94 | pevek
# Processing Record 95 | lebu
# Processing Record 96 | tuktoyaktuk
# Processing Record 97 | jalu
# Processing Record 98 | angoche
# Processing Record 99 | skelleftea
# Processing Record 100 | meulaboh
# Processing Record 101 | moultrie
# Processing Record 102 | taseyevo
# Processing Record 103 | ballina
# Processing Record 104 | salme
# Processing Record 105 | norman wells
# Processing Record 106 | bambanglipuro
# Processing Record 107 | bunbury
# Processing Record 108 | faanui
# Processing Record 109 | turaiyur
# Processing Record 110 | narsaq
# Processing Record 111 | grand-santi
# Processing Record 112 | edd
# Processing Record 113 | plettenberg bay
# Processing Record 114 | the valley
# Processing Record 115 | buraydah
# Processing Record 116 | mingaora
# Processing Record 117 | port hedland
# Processing Record 118 | westport
# City not found. Skipping...
# Processing Record 119 | raymond
# Processing Record 120 | torbay
# Processing Record 121 | bluff
# Processing Record 122 | ilulissat
# Processing Record 123 | atambua
# Processing Record 124 | pisco
# City not found. Skipping...
# Processing Record 125 | launceston
# Processing Record 126 | labuhan
# Processing Record 127 | mar del plata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 128 | yellowknife
# Processing Record 129 | grindavik
# Processing Record 130 | ha tinh
# Processing Record 131 | lipin bor
# Processing Record 132 | lagoa
# Processing Record 133 | palmer
# Processing Record 134 | tomar do geru
# Processing Record 135 | port alfred
# Processing Record 136 | castro
# Processing Record 137 | vardo
# Processing Record 138 | zemio
# Processing Record 139 | cherskiy
# Processing Record 140 | shingu
# Processing Record 141 | san carlos de bariloche
# Processing Record 142 | kedrovyy
# Processing Record 143 | chokurdakh
# Processing Record 144 | havre
# Processing Record 145 | resplendor
# Processing Record 146 | berdigestyakh
# Processing Record 147 | sheltozero
# Processing Record 148 | nikolskoye
# Processing Record 149 | upernavik
# Processing Record 150 | ust-maya
# Processing Record 151 | vuktyl
# Processing Record 152 | sitka
# Processing Record 153 | dong hoi
# Processing Record 154 | coquimbo
# Processing Record 155 | iracoubo
# Processing Record 156 | vao
# Processing Record 157 | miri
# Processing Record 158 | walvis bay
# Processing Record 159 | san patricio
# Processing Record 160 | soyo
# City not found. Skipping...
# Processing Record 161 | bagdarin
# City not found. Skipping...
# Processing Record 162 | touros
# Processing Record 163 | lingyuan
# Processing Record 164 | kudahuvadhoo
# Processing Record 165 | georgetown
# Processing Record 166 | paracuru
# Processing Record 167 | suoyarvi
# Processing Record 168 | ola
# Processing Record 169 | merauke
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 170 | anse-bertrand
# Processing Record 171 | champerico
# Processing Record 172 | mundra
# Processing Record 173 | goderich
# City not found. Skipping...
# Processing Record 174 | la florida
# Processing Record 175 | qaqortoq
# Processing Record 176 | tezu
# Processing Record 177 | lawton
# Processing Record 178 | road town
# City not found. Skipping...
# Processing Record 179 | bambous virieux
# City not found. Skipping...
# Processing Record 180 | de aar
# Processing Record 181 | klaksvik
# Processing Record 182 | luoyang
# Processing Record 183 | zhuhai
# Processing Record 184 | goulburn
# Processing Record 185 | yeniseysk
# City not found. Skipping...
# Processing Record 186 | marienburg
# City not found. Skipping...
# Processing Record 187 | mayo
# Processing Record 188 | port moresby
# City not found. Skipping...
# Processing Record 189 | ridgecrest
# Processing Record 190 | lugoba
# Processing Record 191 | yar-sale
# Processing Record 192 | macia
# Processing Record 193 | saint george
# Processing Record 194 | bemidji
# Processing Record 195 | lardos
# Processing Record 196 | pochutla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 197 | semporna
# Processing Record 198 | tiksi
# Processing Record 199 | pemba
# Processing Record 200 | boende
# Processing Record 201 | mount gambier
# Processing Record 202 | strezhevoy
# Processing Record 203 | hun
# Processing Record 204 | rothenbach
# City not found. Skipping...
# Processing Record 205 | laguna
# Processing Record 206 | kedgwick
# Processing Record 207 | jacareacanga
# City not found. Skipping...
# Processing Record 208 | arraial do cabo
# Processing Record 209 | jilib
# Processing Record 210 | conceicao do araguaia
# Processing Record 211 | alasehir
# Processing Record 212 | komatipoort
# Processing Record 213 | praxedis guerrero
# Processing Record 214 | fallon
# Processing Record 215 | fernie
# Processing Record 216 | maraba
# Processing Record 217 | midland
# Processing Record 218 | turukhansk
# Processing Record 219 | macae
# Processing Record 220 | zyryanovsk
# Processing Record 221 | fort smith
# Processing Record 222 | esperance
# Processing Record 223 | assiniboia
# Processing Record 224 | sheridan
# Processing Record 225 | san quintin
# Processing Record 226 | cape town
# Processing Record 227 | constitucion
# Processing Record 228 | ambilobe
# Processing Record 229 | bumba
# Processing Record 230 | iqaluit
# Processing Record 231 | ambunti
# Processing Record 232 | gushikawa
# Processing Record 233 | fairbanks
# Processing Record 234 | oranjemund
# City not found. Skipping...
# Processing Record 235 | axim
# Processing Record 236 | kon tum
# Processing Record 237 | codrington
# Processing Record 238 | diamantino
# Processing Record 239 | te anau
# City not found. Skipping...
# Processing Record 240 | sosva
# Processing Record 241 | peruibe
# Processing Record 242 | moussoro
# Processing Record 243 | yurga
# Processing Record 244 | tomohon
# Processing Record 245 | zhigansk
# Processing Record 246 | matara
# City not found. Skipping...
# Processing Record 247 | san ramon
# Processing Record 248 | bubaque
# Processing Record 249 | uni
# Processing Record 250 | tuatapere
# Processing Record 251 | dzilam gonzalez
# Processing Record 252 | inta
# City not found. Skipping...
# Processing Record 253 | teknaf
# Processing Record 254 | komsomolskiy
# Processing Record 255 | bayonne
# Processing Record 256 | ambon
# Processing Record 257 | palana
# Processing Record 258 | taltal
# Processing Record 259 | yenangyaung
# Processing Record 260 | bilma
# Processing Record 261 | boyolangu
# Processing Record 262 | longyearbyen
# Processing Record 263 | izazi
# City not found. Skipping...
# Processing Record 264 | kahului
# Processing Record 265 | kaohsiung
# Processing Record 266 | galbshtadt
# Processing Record 267 | turbat
# Processing Record 268 | marevo
# City not found. Skipping...
# Processing Record 269 | harper
# Processing Record 270 | mount kisco
# Processing Record 271 | muyezerskiy
# Processing Record 272 | buala
# Processing Record 273 | ayan
# Processing Record 274 | teguise
# Processing Record 275 | potam
# Processing Record 276 | lufilufi
# Processing Record 277 | albania
# Processing Record 278 | minyar
# Processing Record 279 | havre-saint-pierre
# Processing Record 280 | veraval
# Processing Record 281 | khatanga
# Processing Record 282 | thompson
# Processing Record 283 | bulgan
# Processing Record 284 | anderson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 285 | mutum
# Processing Record 286 | rivne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 287 | narimanov
# Processing Record 288 | luanda
# Processing Record 289 | ziro
# Processing Record 290 | dewas
# Processing Record 291 | melfi
# Processing Record 292 | cabo san lucas
# Processing Record 293 | olinda
# Processing Record 294 | itarema
# Processing Record 295 | hanna
# Processing Record 296 | jalingo
# Processing Record 297 | namibe
# Processing Record 298 | vung tau
# Processing Record 299 | port blair
# Processing Record 300 | truth or consequences
# Processing Record 301 | sibolga
# Processing Record 302 | dingle
# Processing Record 303 | saint-joseph
# Processing Record 304 | bathsheba
# Processing Record 305 | agadir
# Processing Record 306 | kandrian
# Processing Record 307 | padilla
# Processing Record 308 | nyurba
# Processing Record 309 | bereda
# Processing Record 310 | chiclana
# Processing Record 311 | cosamaloapan
# Processing Record 312 | luena
# Processing Record 313 | ossora
# Processing Record 314 | buchanan
# Processing Record 315 | pokhara
# Processing Record 316 | coahuayana
# Processing Record 317 | rundu
# Processing Record 318 | clyde river
# Processing Record 319 | prieska
# Processing Record 320 | portland
# Processing Record 321 | det udom
# Processing Record 322 | rincon
# Processing Record 323 | northam
# Processing Record 324 | linhares
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 325 | kodiak
# Processing Record 326 | oudtshoorn
# Processing Record 327 | burnie
# Processing Record 328 | labuan
# Processing Record 329 | zaysan
# City not found. Skipping...
# Processing Record 330 | tenenkou
# Processing Record 331 | khuzdar
# Processing Record 332 | sumbe
# Processing Record 333 | beira
# Processing Record 334 | santa cruz cabralia
# Processing Record 335 | xining
# Processing Record 336 | revda
# Processing Record 337 | kissidougou
# Processing Record 338 | grand island
# Processing Record 339 | arang
# Processing Record 340 | micheweni
# Processing Record 341 | jian
# Processing Record 342 | sao joao da barra
# Processing Record 343 | severo-kurilsk
# Processing Record 344 | kuznechnoye
# Processing Record 345 | zhangjiakou
# Processing Record 346 | east peoria
# Processing Record 347 | susurluk
# Processing Record 348 | carbonia
# Processing Record 349 | shahrud
# City not found. Skipping...
# Processing Record 350 | chicama
# City not found. Skipping...
# Processing Record 351 | voerde
# Processing Record 352 | hammerfest
# Processing Record 353 | hefei
# Processing Record 354 | muros
# Processing Record 355 | sjovegan
# Processing Record 356 | saint-pierre
# Processing Record 357 | ribnitz-damgarten
# Processing Record 358 | baruun-urt
# City not found. Skipping...
# Processing Record 359 | bariri
# Processing Record 360 | mitchell
# Processing Record 361 | puerto del rosario
# Processing Record 362 | kardla
# Processing Record 363 | inhambane
# City not found. Skipping...
# Processing Record 364 | provideniya
# Processing Record 365 | kavaratti
# Processing Record 366 | seoul
# Processing Record 367 | baiquan
# Processing Record 368 | kakinada
# Processing Record 369 | flagstaff
# Processing Record 370 | hambantota
# Processing Record 371 | segovia
# Processing Record 372 | luza
# Processing Record 373 | nanortalik
# Processing Record 374 | viedma
# Processing Record 375 | blackwater
# Processing Record 376 | guanay
# Processing Record 377 | barcelos
# Processing Record 378 | cabedelo
# Processing Record 379 | ocos
# Processing Record 380 | namatanai
# Processing Record 381 | semenivka
# Processing Record 382 | linda
# City not found. Skipping...
# Processing Record 383 | talnakh
# Processing Record 384 | salinopolis
# Processing Record 385 | novikovo
# Processing Record 386 | glace bay
# Processing Record 387 | port macquarie
# Processing Record 388 | lasa
# Processing Record 389 | rampura
# Processing Record 390 | galesong
# Processing Record 391 | agua verde
# Processing Record 392 | shasta lake
# Processing Record 393 | lompoc
# City not found. Skipping...
# Processing Record 394 | numata
# City not found. Skipping...
# Processing Record 395 | souillac
# Processing Record 396 | itoman
# Processing Record 397 | beringovskiy
# Processing Record 398 | aklavik
# City not found. Skipping...
# Processing Record 399 | dali
# Processing Record 400 | eirunepe
# Processing Record 401 | camden
# Processing Record 402 | sainte-maxime
# Processing Record 403 | poum
# Processing Record 404 | colares
# Processing Record 405 | atocha
# Processing Record 406 | egvekinot
# Processing Record 407 | sivas
# Processing Record 408 | comodoro rivadavia
# Processing Record 409 | sembakung
# Processing Record 410 | san policarpo
# Processing Record 411 | bonavista
# Processing Record 412 | dauphin
# Processing Record 413 | north vanlaiphai
# Processing Record 414 | taraz
# Processing Record 415 | lorengau
# Processing Record 416 | anadyr
# Processing Record 417 | volchikha
# Processing Record 418 | marshall
# City not found. Skipping...
# Processing Record 419 | petropavlovsk-kamchatskiy
# Processing Record 420 | thinadhoo
# Processing Record 421 | lingao
# Processing Record 422 | lavrentiya
# Processing Record 423 | kamina
# Processing Record 424 | carupano
# Processing Record 425 | honningsvag
# Processing Record 426 | tessalit
# Processing Record 427 | amambai
# Processing Record 428 | margate
# Processing Record 429 | garmsar
# Processing Record 430 | amarpatan
# Processing Record 431 | tiarei
# Processing Record 432 | rio grande
# Processing Record 433 | claveria
# Processing Record 434 | awjilah
# Processing Record 435 | nichinan
# Processing Record 436 | nong phai
# Processing Record 437 | deputatskiy
# Processing Record 438 | tungor
# City not found. Skipping...
# Processing Record 439 | xuddur
# Processing Record 440 | hit
# Processing Record 441 | kalat
# Processing Record 442 | melville
# Processing Record 443 | soto la marina
# Processing Record 444 | yakeshi
# Processing Record 445 | kibala
# Processing Record 446 | grimshaw
# Processing Record 447 | payo
# Processing Record 448 | luwingu
# Processing Record 449 | ouegoa
# Processing Record 450 | tucuman
# Processing Record 451 | gimbi
# Processing Record 452 | terenos
# Processing Record 453 | nanning
# Processing Record 454 | hirara
# Processing Record 455 | pingliang
# City not found. Skipping...
# Processing Record 456 | mount pleasant
# City not found. Skipping...
# Processing Record 457 | salvador
# Processing Record 458 | zhigalovo
# Processing Record 459 | fortuna
# Processing Record 460 | sorong
# Processing Record 461 | ugoofaaru
# Processing Record 462 | honiara
# Processing Record 463 | green river
# Processing Record 464 | loa janan
# Processing Record 465 | semey
# Processing Record 466 | karasjok
# Processing Record 467 | dandong
# Processing Record 468 | alice springs
# Processing Record 469 | carutapera
# Processing Record 470 | port hardy
# Processing Record 471 | naro moru
# Processing Record 472 | vagay
# Processing Record 473 | gao
# Processing Record 474 | jataizinho
# Processing Record 475 | salalah
# Processing Record 476 | hofn
# Processing Record 477 | katsuura
# Processing Record 478 | sabang
# Processing Record 479 | kuching
# City not found. Skipping...
# Processing Record 480 | rio gallegos
# Processing Record 481 | prince rupert
# Processing Record 482 | muravlenko
# Processing Record 483 | marilia
# Processing Record 484 | shitanjing
# Processing Record 485 | caracollo
# Processing Record 486 | hobyo
# Processing Record 487 | saint anthony
# Processing Record 488 | quelimane
# Processing Record 489 | prainha
# Processing Record 490 | dahra
# Processing Record 491 | carnarvon
# Processing Record 492 | juneau
# Processing Record 493 | portsmouth
# Processing Record 494 | ravar
# Processing Record 495 | kangaatsiaq
# Processing Record 496 | monteria
# Processing Record 497 | mayumba
# Processing Record 498 | villamontes
# Processing Record 499 | kirakira
# Processing Record 500 | lindi
# Processing Record 501 | normandin
# Processing Record 502 | norsup
# Processing Record 503 | kibuye
# Processing Record 504 | batagay-alyta
# Processing Record 505 | krasnorechenskiy
# Processing Record 506 | waipawa
# City not found. Skipping...
# Processing Record 507 | karratha
# Processing Record 508 | kurchum
# Processing Record 509 | moose factory
# Processing Record 510 | juegang
# City not found. Skipping...
# Processing Record 511 | nakusp
# Processing Record 512 | bulawayo
# City not found. Skipping...
# Processing Record 513 | trofors
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 514 | ormara
# Processing Record 515 | kawalu
# Processing Record 516 | barguzin
# Processing Record 517 | idritsa
# Processing Record 518 | mamallapuram
# Processing Record 519 | richards bay
# Processing Record 520 | chaumont
# City not found. Skipping...
# Processing Record 521 | ostrovnoy
# Processing Record 522 | los llanos de aridane
# Processing Record 523 | kidal
# City not found. Skipping...
# Processing Record 524 | palu
# Processing Record 525 | mega
# Processing Record 526 | alihe
# Processing Record 527 | beech grove
# Processing Record 528 | scarborough
# Processing Record 529 | guerrero negro
# Processing Record 530 | katobu
# Processing Record 531 | vila franca do campo
# Processing Record 532 | tigil
# Processing Record 533 | mirabad
# City not found. Skipping...
# Processing Record 534 | alyangula
# Processing Record 535 | bontang
# Processing Record 536 | finschhafen
# Processing Record 537 | saint-francois
# Processing Record 538 | cibinong
# Processing Record 539 | tanete
# City not found. Skipping...
# Processing Record 540 | agfalva
# Processing Record 541 | ulaangom
# Processing Record 542 | mandalgovi
# Processing Record 543 | lazaro cardenas
# Processing Record 544 | gezing
# Processing Record 545 | nioro

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          545
# Cloudiness    545
# Country       545
# Date          545
# Humidity      545
# Lat           545
# Lng           545
# Max Temp      545
# Wind Speed    545
# dtype: int64

# %%
# Save data frame to CSV
#weather_data to_csv
weather_data_output = "Output_CSV/weather_data.csv"


# Display data frame head 
weather_data.head()

#export_csv = df.to_csv (r'C:\Users\sobai\Zewari_DataBootcamp_HW\Homework_6_API JSON\export_dataframe.csv', index = None, header=True)
#print(df)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Kavieng          20      PG  1563420000        76  -2.57  150.80
# 1  Puerto Ayora          28      EC  1563420002        93  -0.74  -90.35
# 2          Faya           0      SA  1563420003        37  18.39   42.45
# 3          Chuy          81      UY  1563420004        87 -33.69  -53.46
# 4           Bud          93      NO  1563420005        87  62.91    6.91
#
#    Max Temp  Wind Speed
# 0     83.39       13.24
# 1     70.00        5.99
# 2     69.80        2.55
# 3     54.41       12.97
# 4     55.40        6.93

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=30, color='blue',  edgecolor = 'black', label = 'Lat v. Temp', alpha = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("City Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=30, color='red',  edgecolor = 'black', label = 'Lat v. Temp', alpha = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humididty")
plt.xlabel("City Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=30, color='green',  edgecolor = 'black', label = 'Lat v. Temp', alpha = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("City Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=30, color='yellow',  edgecolor = 'black', label = 'Lat v. Temp', alpha = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("City Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()
